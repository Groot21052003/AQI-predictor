# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv("final_dataset.csv",index_col=0) 
data
# Out:
#                      Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO  \
# City
# Ahmedabad      2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN   0.92
# Ahmedabad      2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN   0.97
# Ahmedabad      2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN  17.40
# Ahmedabad      2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN   1.70
# Ahmedabad      2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN  22.10
# ...                   ...    ...    ...    ...    ...    ...    ...    ...
# Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47   0.47
# Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99   0.52
# Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71   0.48
# Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03   0.52
# Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20   0.59
#
# ...

# %%
data2 = pd.read_csv("final_dataset2.csv",index_col=0) 
data2
# Out:
#                           Datetime  PM2.5   PM10    NO    NO2    NOx   NH3  \
# City
# Ahmedabad      2015-01-01 01:00:00    NaN    NaN  1.00  40.01  36.37   NaN
# Ahmedabad      2015-01-01 02:00:00    NaN    NaN  0.02  27.75  19.73   NaN
# Ahmedabad      2015-01-01 03:00:00    NaN    NaN  0.08  19.32  11.08   NaN
# Ahmedabad      2015-01-01 04:00:00    NaN    NaN  0.30  16.45   9.20   NaN
# Ahmedabad      2015-01-01 05:00:00    NaN    NaN  0.12  14.90   7.85   NaN
# ...                            ...    ...    ...   ...    ...    ...   ...
# Visakhapatnam  2020-06-30 20:00:00   9.50  36.00  2.75  25.57  15.85  4.57
# Visakhapatnam  2020-06-30 21:00:00  17.25  49.25  3.62  33.20  20.62  3.78
# Visakhapatnam  2020-06-30 22:00:00  36.00  71.00  2.20  30.80  18.20  3.67
# Visakhapatnam  2020-06-30 23:00:00  15.75  63.00  1.02  28.90  16.00  3.80
# Visakhapatnam  2020-07-01 00:00:00  15.00  66.00  0.40  26.85  14.05  5.20
#
# ...

# %%
data3 = pd.read_csv("test2.csv",index_col=0) 
data3
# Out:
#                  City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0           Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1           Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2           Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3           Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4           Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...               ...         ...    ...    ...    ...    ...    ...    ...
# 186665  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 186666  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 186667  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 186668  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 186669  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
data3.isna().sum()
# Out:
# City                           0
# Date                           0
# PM2.5                      20808
# PM10                       54923
# NO                         16880
# NO2                        16971
# NOx                        12768
# NH3                        47374
# CO                          3707
# SO2                        21429
# O3                         21818
# Benzene                    15141
# Toluene                    23612
# Xylene                    100131
# AQI                        21650
# AQI_Bucket                     0
# StationId                      0
# StationName                    0
# State                          0
# Status                         0
# Region                         0
# Month                          0
# Year                           0
# Season                         0
# Weekday_or_weekend             0
# Regular_day_or_holiday         0
# AQ_Acceptability               0
# dtype: int64

# %%
start_range = 0
end_range = 118059
indexes_to_drop = data3.index.intersection(range(start_range, end_range))
data3 = data3.drop(indexes_to_drop)

# %%
data3.shape
# Out:
# (68611, 27)

# %%
data3.head()
# Out:
#              City        Date  PM2.5  PM10   NO    NO2    NOx  NH3   CO   SO2  \
# 118059  Hyderabad  2015-01-04    NaN   NaN  3.7  17.19  20.89  NaN  0.3  2.58
# 118060  Hyderabad  2015-01-04    NaN   NaN  3.7  17.19  20.89  NaN  0.3  2.58
# 118061  Hyderabad  2015-01-04    NaN   NaN  3.7  17.19  20.89  NaN  0.3  2.58
# 118062  Hyderabad  2015-01-04    NaN   NaN  3.7  17.19  20.89  NaN  0.3  2.58
# 118063  Hyderabad  2015-01-04    NaN   NaN  3.7  17.19  20.89  NaN  0.3  2.58
#
#         ...                                  StationName      State  Status  \
# 118059  ...  Bollaram Industrial Area, Hyderabad - TSPCB  Telangana  Active
# 118060  ...        Central University, Hyderabad - TSPCB  Telangana  Active
# 118061  ...        ICRISAT Patancheru, Hyderabad - TSPCB  Telangana  Active
# 118062  ...          IDA Pashamylaram, Hyderabad - TSPCB  Telangana  Active
# 118063  ...               Sanathnagar, Hyderabad - TSPCB  Telangana  Active
#
# ...

# %%
start_range = 130095
end_range = 186670
indexes_to_drop = data3.index.intersection(range(start_range, end_range))
data3 = data3.drop(indexes_to_drop)

# %%
data3.tail()
# Out:
#              City        Date  PM2.5  PM10    NO    NO2    NOx   NH3    CO  \
# 130090  Hyderabad  2020-07-01  26.83  66.5  2.94  27.18  16.13  9.32  0.43
# 130091  Hyderabad  2020-07-01  26.83  66.5  2.94  27.18  16.13  9.32  0.43
# 130092  Hyderabad  2020-07-01  26.83  66.5  2.94  27.18  16.13  9.32  0.43
# 130093  Hyderabad  2020-07-01  26.83  66.5  2.94  27.18  16.13  9.32  0.43
# 130094  Hyderabad  2020-07-01  26.83  66.5  2.94  27.18  16.13  9.32  0.43
#
#          SO2  ...                            StationName      State  Status  \
# 130090  6.07  ...  Central University, Hyderabad - TSPCB  Telangana  Active
# 130091  6.07  ...  ICRISAT Patancheru, Hyderabad - TSPCB  Telangana  Active
# 130092  6.07  ...    IDA Pashamylaram, Hyderabad - TSPCB  Telangana  Active
# 130093  6.07  ...         Sanathnagar, Hyderabad - TSPCB  Telangana  Active
# 130094  6.07  ...            Zoo Park, Hyderabad - TSPCB  Telangana  Active
#
# ...

# %%
data3.shape
# Out:
# (12036, 27)

# %%
data3.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket', 'StationId',
#        'StationName', 'State', 'Status', 'Region', 'Month', 'Year', 'Season',
#        'Weekday_or_weekend', 'Regular_day_or_holiday', 'AQ_Acceptability'],
#       dtype='object')

# %%
data3.drop(['City', 'Date','NO','NOx', 'NH3',
        'Benzene', 'Toluene', 'Xylene', 'AQI_Bucket', 'StationId',
       'StationName', 'State', 'Status', 'Region', 'Month', 'Year', 'Season',
       'Weekday_or_weekend', 'Regular_day_or_holiday', 'AQ_Acceptability'],axis=1,inplace=True)

# %%
data3
# Out:
#         PM2.5  PM10    NO2    CO   SO2     O3   AQI
# 118059    NaN   NaN  17.19  0.30  2.58  30.34   NaN
# 118060    NaN   NaN  17.19  0.30  2.58  30.34   NaN
# 118061    NaN   NaN  17.19  0.30  2.58  30.34   NaN
# 118062    NaN   NaN  17.19  0.30  2.58  30.34   NaN
# 118063    NaN   NaN  17.19  0.30  2.58  30.34   NaN
# ...       ...   ...    ...   ...   ...    ...   ...
# 130090  26.83  66.5  27.18  0.43  6.07  13.20  48.0
# 130091  26.83  66.5  27.18  0.43  6.07  13.20  48.0
# 130092  26.83  66.5  27.18  0.43  6.07  13.20  48.0
# 130093  26.83  66.5  27.18  0.43  6.07  13.20  48.0
# 130094  26.83  66.5  27.18  0.43  6.07  13.20  48.0
#
# [12036 rows x 7 columns]

# %%
data3.drop(['SO2'],axis=1,inplace=True)
data3
# Out:
#         PM2.5  PM10    NO2    CO     O3   AQI
# 118059    NaN   NaN  17.19  0.30  30.34   NaN
# 118060    NaN   NaN  17.19  0.30  30.34   NaN
# 118061    NaN   NaN  17.19  0.30  30.34   NaN
# 118062    NaN   NaN  17.19  0.30  30.34   NaN
# 118063    NaN   NaN  17.19  0.30  30.34   NaN
# ...       ...   ...    ...   ...    ...   ...
# 130090  26.83  66.5  27.18  0.43  13.20  48.0
# 130091  26.83  66.5  27.18  0.43  13.20  48.0
# 130092  26.83  66.5  27.18  0.43  13.20  48.0
# 130093  26.83  66.5  27.18  0.43  13.20  48.0
# 130094  26.83  66.5  27.18  0.43  13.20  48.0
#
# [12036 rows x 6 columns]

# %%
data3.reset_index(drop=True,inplace=True)
data3
# Out:
#        PM2.5  PM10    NO2    CO     O3   AQI
# 0        NaN   NaN  17.19  0.30  30.34   NaN
# 1        NaN   NaN  17.19  0.30  30.34   NaN
# 2        NaN   NaN  17.19  0.30  30.34   NaN
# 3        NaN   NaN  17.19  0.30  30.34   NaN
# 4        NaN   NaN  17.19  0.30  30.34   NaN
# ...      ...   ...    ...   ...    ...   ...
# 12031  26.83  66.5  27.18  0.43  13.20  48.0
# 12032  26.83  66.5  27.18  0.43  13.20  48.0
# 12033  26.83  66.5  27.18  0.43  13.20  48.0
# 12034  26.83  66.5  27.18  0.43  13.20  48.0
# 12035  26.83  66.5  27.18  0.43  13.20  48.0
#
# [12036 rows x 6 columns]

# %%
data3.fillna(value=0,inplace=True)
data3
# Out:
#        PM2.5  PM10    NO2    CO     O3   AQI
# 0       0.00   0.0  17.19  0.30  30.34   0.0
# 1       0.00   0.0  17.19  0.30  30.34   0.0
# 2       0.00   0.0  17.19  0.30  30.34   0.0
# 3       0.00   0.0  17.19  0.30  30.34   0.0
# 4       0.00   0.0  17.19  0.30  30.34   0.0
# ...      ...   ...    ...   ...    ...   ...
# 12031  26.83  66.5  27.18  0.43  13.20  48.0
# 12032  26.83  66.5  27.18  0.43  13.20  48.0
# 12033  26.83  66.5  27.18  0.43  13.20  48.0
# 12034  26.83  66.5  27.18  0.43  13.20  48.0
# 12035  26.83  66.5  27.18  0.43  13.20  48.0
#
# [12036 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
data_train,data_test=train_test_split(data3,test_size=0.2,random_state=2)
data_train.reset_index(drop=True,inplace=True)
data_test.reset_index(drop=True,inplace=True)

# %%
x_train=data_train.drop(["AQI"],axis=1)
y_train=data_train["AQI"]
x_test=data_test.drop(["AQI"],axis=1)
y_test=data_test["AQI"]

# %%
x_train
# Out:
#       PM2.5    PM10    NO2    CO     O3
# 0     79.18  164.76  60.89  1.00  58.03
# 1     55.10  107.95  48.47  0.64  27.57
# 2     36.05  146.83  23.87  0.43  47.23
# 3     62.77  102.95  10.25  0.89  50.96
# 4     55.60  118.88  49.58  0.57  33.69
# ...     ...     ...    ...   ...    ...
# 9623  29.42   80.62   8.10  0.87  24.43
# 9624  44.09  147.59  35.83  0.62  35.20
# 9625  72.38  141.02  54.79  1.16  48.64
# 9626  41.44   75.47   9.64  0.75  38.46
# 9627  33.83   74.91  31.53  0.63  45.59
#
# [9628 rows x 5 columns]

# %%
y_train
# Out:
# 0       174.0
# 1       104.0
# 2       119.0
# 3       120.0
# 4       108.0
#         ...
# 9623    100.0
# 9624    122.0
# 9625    140.0
# 9626     98.0
# 9627    101.0
# Name: AQI, Length: 9628, dtype: float64

# %%
x_test
# Out:
#        PM2.5    PM10    NO2    CO     O3
# 0      20.60    0.00  15.87  8.83   9.17
# 1      11.98   35.51  42.12  0.03  22.95
# 2      40.12    0.00  18.06  1.83  32.89
# 3      15.95   38.56   8.82  0.39  19.48
# 4      14.52   43.56  24.38  0.27  17.72
# ...      ...     ...    ...   ...    ...
# 2403  177.62   98.01  25.50  1.73  25.90
# 2404   37.00    0.00   9.01  0.72  23.39
# 2405   57.22  103.72  19.75  1.28  31.38
# 2406   57.96   98.74   8.84  0.82  47.36
# 2407    0.00    0.00  21.35  0.47   9.41
#
# [2408 rows x 5 columns]

# %%
y_test
# Out:
# 0       248.0
# 1        47.0
# 2       157.0
# 3        42.0
# 4        54.0
#         ...
# 2403    213.0
# 2404    108.0
# 2405    120.0
# 2406    121.0
# 2407      0.0
# Name: AQI, Length: 2408, dtype: float64

# %%
rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=rf.predict(x_test)

# %%
y2_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
mse1 = mean_squared_error(y_test, y_pred) # random forest regression
mse1
# Out:
# 25.817334767440823

# %%
r2_score(y_test, y_pred)#random forest regression  close to 1 is good sign
# Out:
# 0.9930025223819531

# %%
mse2 = mean_squared_error(y_test, y2_pred)#linear regression
mse2
# Out:
# 1067.9504117983683
